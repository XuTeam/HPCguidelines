# %%
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# h1 loss
# kernel size 3

import FNOtuning_hopt_multi
config={
        "modes": 12,
        "width": 32,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "sampling_rate": 2,
    }
FNOtuning_hopt_multi.objective(**config)
# Out:
# 2392513
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.01711557000875473

# %%
# l2 loss
# kernel size 3

import FNOtuning_hopt_multi
config={
        "modes": 12,
        "width": 32,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "sampling_rate": 2,
        "loss_type":'l2',
    }
FNOtuning_hopt_multi.objective(**config)
# Out:
# 2392513
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.01574590563774109

# %%
# h1 loss
# kernel size 3
# a4f1
import FNOtuning_hopt_multi
config={
        "modes": 12,
        "width": 32,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "sampling_rate": 2,
        "loss_type":'h1',
    }
FNOtuning_hopt_multi.objective(**config)
# Out:
# 2392513
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.024049986004829407

# %%
# l2 loss
# kernel size 3
# a4f1
import FNOtuning_hopt_multi
config={
        "modes": 12,
        "width": 32,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "sampling_rate": 2,
        "loss_type":'l2',
    }
FNOtuning_hopt_multi.objective(**config)
# Out:
# 2392513
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.018468378484249114
