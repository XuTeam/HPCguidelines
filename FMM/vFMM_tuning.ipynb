# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import vFMM_multi
config={
        "modes": 12,
        "width": 32,
        "data": 'darcy',
        "sampling_rate": 3,
        "padding": 5,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "batch_size": 20,
        "optimizer_type": 'adam',
        
    }
vFMM_multi.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 3278639
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.006018528491258621

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import vFMM_multi
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy',
        "sampling_rate": 3,
        "padding": 5,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "batch_size": 20,
        "optimizer_type": 'adam',
        
    }
vFMM_multi.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 13170671
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.004903535321354866

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import vFMM_multi
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy20',
        "sampling_rate": 2,
        "padding": 5,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "batch_size": 20,
        "optimizer_type": 'adam',
        
    }
vFMM_multi.objective(**config)
# Out:
# 13030758
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.0038858581334352492

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy20',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# 9593601
#   0%|          | 0/100 [00:00<?, ?it/s]
