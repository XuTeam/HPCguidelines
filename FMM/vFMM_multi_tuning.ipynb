# %%
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# h1 loss, lower resolution
# kernel size 3
import vFMM_multi
config={
        "modes": 14,
        "width": 64,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "batch_size": 5,
    }
vFMM_multi.objective(**config)
# Out:
# 14077988
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.016835082061588763

# %%
# h1 loss, lower resolution
# kernel size 3
import vFMM_multi
config={
        "modes": 14,
        "width": 32,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "batch_size": 5,
    }
vFMM_multi.objective(**config)
# Out:
# 3524068
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# h1 loss, lower resolution
# kernel size 3
import vFMM_multi
config={
        "modes": 16,
        "width": 64,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "batch_size": 5,
        "sampling_rate": 4,
    }
vFMM_multi.objective(**config)
# Out:
# 18010148
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# h1 loss, lower resolution
# kernel size 3
import vFMM_multi
config={
        "modes": 16,
        "width": 64,
        "learning_rate": 2e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "batch_size": 5,
        "sampling_rate": 4,
    }
vFMM_multi.objective(**config)
# Out:
# 18010148
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.020046347826719282

# %%
# h1 loss, lower resolution
# kernel size 3
import vFMM_multi
config={
        "modes": 16,
        "width": 32,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "batch_size": 5,
    }
vFMM_multi.objective(**config)
# Out:
# 4507108
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.014481789506971836

# %%
# h1 loss, lower resolution
# kernel size 3
import vFMM_multi
config={
        "modes": 16,
        "width": 32,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "batch_size": 5,
        "sampling_rate": 4,
        "optimizer_type": 'adamw',
        "loss_type": 'h1',
        "epochs": 200,
    }
vFMM_multi.objective(**config)
# Out:
# 4507332
#   0%|          | 0/200 [00:00<?, ?it/s]
# 0.009930110983550549

# %%
# h1 loss, lower resolution
# kernel size 3
import vFMM_multi
config={
        "modes": 16,
        "width": 64,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "batch_size": 10,
        "sampling_rate": 4,
        "optimizer_type": 'adamw',
        "loss_type": 'h1',
        "epochs": 200,
    }
vFMM_multi.objective(**config)
# Out:
# 18010596
#   0%|          | 0/200 [00:00<?, ?it/s]
# 0.010575390830636024

# %%
# h1 loss, lower resolution
# kernel size 3
import vFMM_multi
config={
        "modes": 16,
        "width": 32,
        "learning_rate": 1e-3,
        "weight_decay": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "batch_size": 5,
        "sampling_rate": 4,
        "padding": 15,
        "optimizer_type": 'adamw',
        "loss_type": 'h1',
        "epochs": 200,
    }
vFMM_multi.objective(**config)
# Out:
# 4507332
#   0%|          | 0/200 [00:00<?, ?it/s]
# 0.009886837974190711

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
from vFMM_multi import *
config={
        "modes": 12,
        "width": 32,
        "data": 'checker',
        "sampling_rate": 4,
        "padding": 15,
        "learning_rate": 2e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "batch_size": 10,
        "optimizer_type": 'adamw',
        
    }
locals().update(config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
################################################################
# configs
################################################################
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if data=='a3f2':
    TRAIN_PATH = os.path.join(os.path.abspath(''), 'data/mul_res1023_a3f2_train.mat')
    TEST_PATH = os.path.join(os.path.abspath(''), 'data/mul_res1023_a3f2_test.mat')
elif data=='a4f1':
    TRAIN_PATH = os.path.join(os.path.abspath(''), 'data/mul_res1023_a4f1_train.mat')
    TEST_PATH = os.path.join(os.path.abspath(''), 'data/mul_res1023_a4f1_test.mat')
elif data=='darcy':
    TRAIN_PATH = os.path.join(os.path.abspath(''),'data/piececonst_r421_N1024_smooth1.mat')
    TEST_PATH = os.path.join(os.path.abspath(''), 'data/piececonst_r421_N1024_smooth2.mat')
elif data=='checker':
    TRAIN_PATH = '/home/xubo/multiscale-attention/data/mul_res1023_a7f1m32_train.mat'
    TEST_PATH = '/home/xubo/multiscale-attention/data/mul_res1023_a7f1m32_test.mat'
else: raise NameError('invalid data name')

ntrain = 1000
ntest = 100

epochs = epochs
step_size = 100
gamma = 0.5

r = sampling_rate

################################################################
# load data and data normalization
################################################################
reader = MatReader(TRAIN_PATH)
x_train = reader.read_field('coeff')[:ntrain,...]
y_train = reader.read_field('sol')[:ntrain,::r,::r]
s = y_train.size(1)
# s = int(((1023 - 1)//r) + 1)

reader.load_file(TEST_PATH)
x_test = reader.read_field('coeff')[:ntest,...]
y_test = reader.read_field('sol')[:ntest,::r,::r]

x_normalizer = UnitGaussianNormalizer(x_train)
# x_train = x_normalizer.encode(x_train)
# x_test = x_normalizer.encode(x_test)
x_train = x_train/10
x_test = x_test/10

y_normalizer = UnitGaussianNormalizer(y_train)
y_normalizer.cuda(device)

x_train = x_train[:, np.newaxis, ...]
x_test = x_test[:, np.newaxis, ...]

train_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train.contiguous(), y_train.contiguous()), batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test.contiguous(), y_test.contiguous()), batch_size=batch_size, shuffle=False)

# %%
################################################################
# training and evaluation
################################################################
model = FMMTransformer(img_size=1023, patch_size=4, in_chans=1, num_classes=2,
                 embed_dim=width-2, depths=[1, 1, 1], num_heads=[1, 1, 1],
                 window_size=[8, 8, 8], mlp_ratio=4., qkv_bias=False, qk_scale=None,
                 drop_rate=0., attn_drop_rate=0., drop_path_rate=0.,
                 norm_layer=nn.LayerNorm, ape=False, patch_norm=None,
                 use_checkpoint=False, stride=sampling_rate).to(device)

FNOdecoder = FNO2d(modes, modes, width, num_spectral_layers=num_spectral_layers, mlp_hidden_dim=mlp_hidden_dim, mode_threshold=mode_threshold, kernel_type=kernel_type, padding=padding, resolution=s).to(device)
print(count_params(model) + count_params(FNOdecoder))

if optimizer_type.lower()=='adam':
    optimizer = Adam(set(model.parameters()) | set(FNOdecoder.parameters()), lr=learning_rate, weight_decay=weight_decay)
else:
    optimizer = torch.optim.AdamW(set(model.parameters()) | set(FNOdecoder.parameters()), lr=learning_rate, weight_decay=weight_decay)

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=learning_rate, 
                           div_factor=1e1, 
                           final_div_factor=1e1,
                           pct_start=0.2,
                           steps_per_epoch=1, 
                           epochs=epochs)

h1loss = HsLoss(d=2, p=2, k=1, size_average=False, res=s, a=[2.,])
h1loss.cuda(device)
l2loss = LpLoss(size_average=False)  

train_h1_rec, train_l2_rec, train_f_dist_rec, test_l2_rec, test_h1_rec = [], [], [], [], []
# Out:
# 2646806

# %%
x, y = next(iter(train_loader))
x, y = x.to(device), y.to(device)

# %%
model(x).shape
# Out:
# torch.Size([10, 256, 256, 30])

# %%
grid = FNOdecoder.get_grid(model(x).shape, x.device)

# %%
grid.shape
# Out:
# torch.Size([10, 256, 256, 2])

# %%
x = torch.cat((model(x), grid), dim=-1)

# %%
x.shape
# Out:
# torch.Size([10, 256, 256, 64])

# %%
test = FNOdecoder(model(x))

# %%
with tqdm(total=epochs) as pbar_ep:

    for epoch in range(epochs):
        model.train()
        FNOdecoder.train()
        train_l2, train_h1 = 0, 0
        train_f_dist = torch.zeros(s)
        for x, y in train_loader:
            x, y = x.to(device), y.to(device) 
            optimizer.zero_grad()
            out = torch.squeeze(FNOdecoder(model(x)))
            out = y_normalizer.decode(out)
            if loss_type=='h1':
                with torch.no_grad():
                    train_l2loss = l2loss(out, y)

                train_h1loss, train_f_l2loss, f_l2x, f_l2y = h1loss(out, y)
                train_h1loss.backward()
            else:
                with torch.no_grad():
                    train_h1loss, train_f_l2loss, f_l2x, f_l2y = h1loss(out, y)

                train_l2loss = l2loss(out, y)
                train_l2loss.backward()

            optimizer.step()
            train_h1 += train_h1loss.item()
            train_l2 += train_l2loss.item()
            train_f_dist += sum(torch.squeeze(torch.abs(f_l2x-f_l2y))).cpu()

        ############################
        lr = optimizer.param_groups[0]['lr']

        scheduler.step()

        model.eval()
        FNOdecoder.eval()
        test_l2, test_h1 = 0., 0.

        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                out = torch.squeeze(FNOdecoder(model(x)))
                out = y_normalizer.decode(out)
                test_l2 += l2loss(out, y).item()
                test_h1 += h1loss(out, y)[0].item()

        train_l2/= ntrain
        train_h1/= ntrain
        test_l2 /= ntest
        test_h1/= ntest
        train_f_dist/= ntrain

        train_l2_rec.append(train_l2); test_l2_rec.append(test_l2); train_h1_rec.append(train_h1); test_h1_rec.append(test_h1)
        train_f_dist_rec.append(train_f_dist)

        desc = f"epoch: [{epoch+1}/{epochs}]"
        desc += f" | current lr: {lr:.3e}"
        desc += f"| train l2 loss: {train_l2:.3e} "
        desc += f"| train h1 loss: {train_h1:.3e} "
        desc += f"| val l2 loss: {test_l2:.3e} "
        desc += f"| val h1 loss: {test_h1:.3e} "
        pbar_ep.set_description(desc)
        pbar_ep.update()

    if show_conv:
        plt.figure(1)
        plt.semilogy(np.array(train_l2_rec), label='train l2 loss')
        plt.semilogy(np.array(train_h1_rec), label='train h1 loss')
        plt.semilogy(np.array(test_l2_rec), label='valid l2 loss')
        plt.semilogy(np.array(test_h1_rec), label='valid h1 loss')
        plt.grid(True, which="both", ls="--")
        plt.legend()
        plt.show()

        temp = torch.stack(train_f_dist_rec)
        plt.figure()
        plt.semilogy(temp[:, 0:6].detach().cpu().numpy())
        plt.grid(True, which="both", ls="--")
        plt.legend(range(6))
        plt.show()

        plt.figure()
        plt.semilogy(temp[:, 10:16].detach().cpu().numpy())
        plt.grid(True, which="both", ls="--")
        plt.legend(range(10,16))
        plt.show()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from vFMM_multi import *
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2
from vFMM_multi import *
from fourier_2d_hopt_train import getPath
from scipy.linalg import svd

data = 'darcy20c6'
TRAIN_PATH, TEST_PATH = getPath(data)
reader = MatReader(TRAIN_PATH)
x_test = reader.read_field('coeff')[:,...]
y_test = reader.read_field('sol')[:,...]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
y_test_cpu = y_test.contiguous().reshape([y_test.size(0), -1]).numpy()
(U, s_darcy_c6, Va) = svd(y_test_cpu, full_matrices=False)

# %%
data = 'darcy'
TRAIN_PATH, TEST_PATH = getPath(data)
reader = MatReader(TEST_PATH)
x_test = reader.read_field('coeff')[:,...]
y_test = reader.read_field('sol')[:,...]
y_test_cpu = y_test.contiguous().reshape([y_test.size(0), -1]).numpy()
(U, s_darcy, Va) = svd(y_test_cpu, full_matrices=False)

# %%
plt.figure()
plt.semilogy(s_darcy_c6, 'o')
plt.semilogy(s_darcy, '*')
plt.semilogy(s_checker, 's')
plt.semilogy(s_checker_m4, '^')
plt.legend(['darcy20c6', 'darcy', 'checker','checker_m4'])
plt.show()

# %%
data = 'checker'
TRAIN_PATH, TEST_PATH = getPath(data)
reader = MatReader(TRAIN_PATH)
x_test = reader.read_field('coeff')[:,...]
y_test = reader.read_field('sol')[:,...]
y_test_cpu = y_test.contiguous().reshape([y_test.size(0), -1]).numpy()
(U, s_checker, Va) = svd(y_test_cpu, full_matrices=False)

# %%
data = 'checkerm4'
TRAIN_PATH, TEST_PATH = getPath(data)
reader = MatReader(TRAIN_PATH)
x_test = reader.read_field('coeff')[:,...]
y_test = reader.read_field('sol')[:,...]
y_test_cpu = y_test.contiguous().reshape([y_test.size(0), -1]).numpy()
(U, s_checker_m4, Va) = svd(y_test_cpu, full_matrices=False)

# %%
Z = x_test[i,::2,::2].cpu().numpy()
    
X = np.linspace(0, 1, Z.shape[-1])
Y = np.linspace(0, 1, Z.shape[-1])
X, Y = np.meshgrid(X, Y)

plt.figure()
surf = plt.contour(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
plt.show()
# Out:
# <ipython-input-16-3ee6561f540a>:8: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   surf = plt.contour(X, Y, Z, cmap=cm.coolwarm,

# %%
for i in range(2):
    fig, (ax1,ax2) = plt.subplots(1,2)
    #,subplot_kw={"projection": "3d"}
    # Make data.
    

    Z = x_test[i,::2,::2].cpu().numpy()
    
    X = np.linspace(0, 1, Z.shape[-1])
    Y = np.linspace(0, 1, Z.shape[-1])
    X, Y = np.meshgrid(X, Y)
    R = np.sqrt(X**2 + Y**2)
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax1.contour(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax1.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax1.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

#     plt.show()

    Z = y_test[i,::2,::2].cpu().numpy()
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax2.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
#     ax2.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
#     ax2.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

    plt.show()
# Out:
# <ipython-input-14-626e94dccde6>:15: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   surf = ax1.contour(X, Y, Z, cmap=cm.coolwarm,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-626e94dccde6> in <module>
#      18     # Customize the z axis.
#      19     # ax.set_zlim(-1.01, 1.01)
# ---> 20     ax1.zaxis.set_major_locator(LinearLocator(10))
#      21     # A StrMethodFormatter is used automatically
#      22     ax1.zaxis.set_major_formatter('{x:.02f}')
#
# AttributeError: 'AxesSubplot' object has no attribute 'zaxis'

# %%
for i in range(5):
    fig, (ax1,ax2) = plt.subplots(1,2,subplot_kw={"projection": "3d"})

    # Make data.
    

    Z = x_test[i,::2,::2].cpu().numpy()
    
    X = np.linspace(0, 1, Z.shape[-1])
    Y = np.linspace(0, 1, Z.shape[-1])
    X, Y = np.meshgrid(X, Y)
    R = np.sqrt(X**2 + Y**2)
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax1.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax1.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax1.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

#     plt.show()

    Z = y_test[i,::2,::2].cpu().numpy()
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax2.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax2.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax2.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

    plt.show()

# %%
for i in range(5):
    fig, (ax1,ax2) = plt.subplots(1,2,subplot_kw={"projection": "3d"})

    # Make data.
    

    Z = x_test[i,::2,::2].cpu().numpy()
    
    X = np.linspace(0, 1, Z.shape[-1])
    Y = np.linspace(0, 1, Z.shape[-1])
    X, Y = np.meshgrid(X, Y)
    R = np.sqrt(X**2 + Y**2)
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax1.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

#     plt.show()

    Z = y_test[i,::2,::2].cpu().numpy()
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax2.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

    plt.show()

# %%
reader = MatReader(TEST_PATH)
x_test = reader.read_field('coeff')[:,...]
y_test = reader.read_field('sol')[:,...]

# %%
y_test_cpu = y_test.contiguous().reshape([y_test.shape[0], -1]).numpy()
from scipy.linalg import svd
(U, s, Va) = svd(y_test_cpu, full_matrices=False)
plt.plot(s)
plt.show()

# %%
plt.semilogy(s)
plt.show()

# %%
for i in range(5):
    fig, (ax1,ax2) = plt.subplots(1,2,subplot_kw={"projection": "3d"})

    # Make data.
    

    Z = x_test[i,::2,::2].cpu().numpy()
    
    X = np.linspace(0, 1, Z.size(-1))
    Y = np.linspace(0, 1, Z.size(-1))
    X, Y = np.meshgrid(X, Y)
    R = np.sqrt(X**2 + Y**2)
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax1.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

#     plt.show()

    Z = y_test[i,::2,::2].cpu().numpy()
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax2.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

    plt.show()

# %%
data = 'checker'

if data=='a3f2':
    TRAIN_PATH = os.path.join(os.path.abspath(''), 'data/mul_res1023_a3f2_train.mat')
    TEST_PATH = os.path.join(os.path.abspath(''), 'data/mul_res1023_a3f2_test.mat')
elif data=='a4f1':
    TRAIN_PATH = os.path.join(os.path.abspath(''), 'data/mul_res1023_a4f1_train.mat')
    TEST_PATH = os.path.join(os.path.abspath(''), 'data/mul_res1023_a4f1_test.mat')
elif data=='darcy':
    TRAIN_PATH = os.path.join(os.path.abspath(''),'data/piececonst_r421_N1024_smooth1.mat')
    TEST_PATH = os.path.join(os.path.abspath(''), 'data/piececonst_r421_N1024_smooth2.mat')
elif data=='checker':
    TRAIN_PATH = '/home/xubo/multiscale-attention/data/mul_res1023_a7f1m4_train.mat'
    TEST_PATH = '/home/xubo/multiscale-attention/data/mul_res1023_a7f1m4_test.mat'
else: raise NameError('invalid data name')

reader = MatReader(TRAIN_PATH)
x_test = reader.read_field('coeff')[:,...]
y_test = reader.read_field('sol')[:,...]

y_test_cpu = y_test.contiguous().reshape([1000, -1]).numpy()
from scipy.linalg import svd
(U, s, Va) = svd(y_test_cpu, full_matrices=False)
plt.plot(s)
plt.show()

plt.semilogy(s)
plt.show()

for i in range(5):
    fig, (ax1,ax2) = plt.subplots(1,2,subplot_kw={"projection": "3d"})

    # Make data.
    

    Z = x_test[i,::2,::2].cpu().numpy()
    
    X = np.linspace(0, 1, Z.shape[-1])
    Y = np.linspace(0, 1, Z.shape[-1])
    X, Y = np.meshgrid(X, Y)
    R = np.sqrt(X**2 + Y**2)
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax1.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

#     plt.show()

    Z = y_test[i,::2,::2].cpu().numpy()
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax2.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-b77151248ba0> in <module>
#      36     Z = x_test[i,::2,::2].cpu().numpy()
#      37
# ---> 38     X = np.linspace(0, 1, Z.size(-1))
#      39     Y = np.linspace(0, 1, Z.size(-1))
#      40     X, Y = np.meshgrid(X, Y)
#
# TypeError: 'int' object is not callable

# %%
for i in range(10,15):
    fig, (ax1,ax2) = plt.subplots(1,2,subplot_kw={"projection": "3d"})

    # Make data.
    

    Z = x_test[i,::2,::2].cpu().numpy()
    
    X = np.linspace(0, 1, Z.shape[-1])
    Y = np.linspace(0, 1, Z.shape[-1])
    X, Y = np.meshgrid(X, Y)
    R = np.sqrt(X**2 + Y**2)
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax1.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

#     plt.show()

    Z = y_test[i,::2,::2].cpu().numpy()
    # Z = np.sin(R)
    # Plot the surface.
    surf = ax2.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    # ax.set_zlim(-1.01, 1.01)
    ax.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
#     fig.colorbar(surf, shrink=0.5, aspect=5)

    plt.show()

# %%
plt.figure(1)
plt.semilogy(np.array(train_l2_rec), label='train l2 loss')
plt.semilogy(np.array(train_h1_rec), label='train h1 loss')
plt.semilogy(np.array(test_l2_rec), label='valid l2 loss')
plt.semilogy(np.array(test_h1_rec), label='valid h1 loss')
plt.grid(True, which="both", ls="--")
plt.legend()
plt.show()

temp = torch.stack(train_f_dist_rec)
plt.figure()
plt.semilogy(temp[:, 0:6].detach().cpu().numpy())
plt.grid(True, which="both", ls="--")
plt.legend(range(6))
plt.show()

plt.figure()
plt.semilogy(temp[:, 10:16].detach().cpu().numpy())
plt.grid(True, which="both", ls="--")
plt.legend(range(10,16))
plt.show()

# %%
del x, y, FNOdecoder, model

# %%
torch.cuda.empty_cache()

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
from vFMM_multi import *
config={
        "modes": 12,
        "width": 32,
        "data": 'a4f1',
        "sampling_rate": 4,
        "padding": 15,
        "learning_rate": 5e-4,
        "weight_decay": 5e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 200,
        "loss_type": 'l2',
        "batch_size": 10,
        "optimizer_type": 'adam',
        
    }
locals().update(config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
if optimizer_type.lower()=='adam':
    optimizer = Adam(set(model.parameters()) | set(FNOdecoder.parameters()), lr=learning_rate, weight_decay=weight_decay)
else:
    optimizer = torch.optim.AdamW(set(model.parameters()) | set(FNOdecoder.parameters()), lr=learning_rate, weight_decay=weight_decay)
    
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.8)

with tqdm(total=epochs) as pbar_ep:

    for epoch in range(epochs):
        model.train()
        FNOdecoder.train()
        train_l2, train_h1 = 0, 0
        train_f_dist = torch.zeros(s)
        for x, y in train_loader:
            x, y = x.to(device), y.to(device) 
            optimizer.zero_grad()
            out = torch.squeeze(FNOdecoder(model(x)))
            out = y_normalizer.decode(out)
            if loss_type=='h1':
                with torch.no_grad():
                    train_l2loss = l2loss(out, y)

                train_h1loss, train_f_l2loss, f_l2x, f_l2y = h1loss(out, y)
                train_h1loss.backward()
            else:
                with torch.no_grad():
                    train_h1loss, train_f_l2loss, f_l2x, f_l2y = h1loss(out, y)

                train_l2loss = l2loss(out, y)
                train_l2loss.backward()

            optimizer.step()
            train_h1 += train_h1loss.item()
            train_l2 += train_l2loss.item()
            train_f_dist += sum(torch.squeeze(torch.abs(f_l2x-f_l2y))).cpu()

        ############################
        lr = optimizer.param_groups[0]['lr']

        scheduler.step()

        model.eval()
        FNOdecoder.eval()
        test_l2, test_h1 = 0., 0.

        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                out = torch.squeeze(FNOdecoder(model(x)))
                out = y_normalizer.decode(out)
                test_l2 += l2loss(out, y).item()
                test_h1 += h1loss(out, y)[0].item()

        train_l2/= ntrain
        train_h1/= ntrain
        test_l2 /= ntest
        test_h1/= ntest
        train_f_dist/= ntrain

        train_l2_rec.append(train_l2); test_l2_rec.append(test_l2); train_h1_rec.append(train_h1); test_h1_rec.append(test_h1)
        train_f_dist_rec.append(train_f_dist)

        desc = f"epoch: [{epoch+1}/{epochs}]"
        desc += f" | current lr: {lr:.3e}"
        desc += f"| train l2 loss: {train_l2:.3e} "
        desc += f"| train h1 loss: {train_h1:.3e} "
        desc += f"| val l2 loss: {test_l2:.3e} "
        desc += f"| val h1 loss: {test_h1:.3e} "
        pbar_ep.set_description(desc)
        pbar_ep.update()

    if show_conv:
        plt.figure(1)
        plt.semilogy(np.array(train_l2_rec), label='train l2 loss')
        plt.semilogy(np.array(train_h1_rec), label='train h1 loss')
        plt.semilogy(np.array(test_l2_rec), label='valid l2 loss')
        plt.semilogy(np.array(test_h1_rec), label='valid h1 loss')
        plt.grid(True, which="both", ls="--")
        plt.legend()
        plt.show()

        temp = torch.stack(train_f_dist_rec)
        plt.figure()
        plt.semilogy(temp[:, 0:6].detach().cpu().numpy())
        plt.grid(True, which="both", ls="--")
        plt.legend(range(6))
        plt.show()

        plt.figure()
        plt.semilogy(temp[:, 10:16].detach().cpu().numpy())
        plt.grid(True, which="both", ls="--")
        plt.legend(range(10,16))
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-7bbd141e5ba2> in <module>
#       1 if optimizer_type.lower()=='adam':
# ----> 2     optimizer = Adam(set(model.parameters()) | set(FNOdecoder.parameters()), lr=learning_rate, weight_decay=weight_decay)
#       3 else:
#       4     optimizer = torch.optim.AdamW(set(model.parameters()) | set(FNOdecoder.parameters()), lr=learning_rate, weight_decay=weight_decay)
#       5
#
# NameError: name 'model' is not defined

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import vFMM_multi
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy20c6',
        "sampling_rate": 2,
        "padding": 5,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "batch_size": 20,
        "optimizer_type": 'adam',
        
    }
vFMM_multi.objective(**config)
# Out:
# 13030758
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.29654685020446775

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import vFMM_multi
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy20c6',
        "sampling_rate": 2,
        "padding": 5,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "batch_size": 20,
        "optimizer_type": 'adam',
        "GN": False,
        
    }
vFMM_multi.objective(**config)
# Out:
# 13030758
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.05672497391700745

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import vFMM_multi
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy20c6',
        "sampling_rate": 2,
        "padding": 5,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "batch_size": 20,
        "optimizer_type": 'adam',
        "GN": False,
        
    }
vFMM_multi.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 13030758
# /home/liux0t/miniconda3/envs/anconda3/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1640811803361/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|          | 0/100 [00:00<?, ?it/s]
# [W Copy.cpp:244] Warning: Casting complex values to real discards the imaginary part (function operator())
# 0.01163008525967598

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import vFMM_multi
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy20c6',
        "sampling_rate": 2,
        "padding": 5,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "batch_size": 20,
        "optimizer_type": 'adam',
        "GN": False,
        
    }
vFMM_multi.objective(**config)
# Out:
# /home/liux0t/miniconda3/envs/anconda3/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1640811803361/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 13030758
#   0%|          | 0/100 [00:00<?, ?it/s]
# [W Copy.cpp:244] Warning: Casting complex values to real discards the imaginary part (function operator())
# 0.05938677370548248

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import vFMM_multi
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy15c10',
        "sampling_rate": 2,
        "padding": 5,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "batch_size": 20,
        "optimizer_type": 'adam',
        "GN": False,        
        }
vFMM_multi.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/liux0t/miniconda3/envs/anconda3/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1640811803361/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 13030758
#   0%|          | 0/100 [00:00<?, ?it/s]
# [W Copy.cpp:244] Warning: Casting complex values to real discards the imaginary part (function operator())
# 0.006810594722628594

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import vFMM_multi
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy15c10',
        "sampling_rate": 2,
        "padding": 5,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 1000,
        "loss_type": 'h1',
        "batch_size": 50,
        "optimizer_type": 'adam',
        "GN": False, 
        "final_div_factor": 1e2,
        }
vFMM_multi.objective(**config)
# Out:
# /home/liux0t/miniconda3/envs/anconda3/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1640811803361/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 13030758
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [W Copy.cpp:244] Warning: Casting complex values to real discards the imaginary part (function operator())
# 0.00589178204536438
