# %%
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# l2 loss
# kernel size 3
import vFMM_multi
config={
        "modes": 14,
        "width": 64,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "batch_size": 5,
    }
vFMM_multi.objective(**config)
# Out:
# 14077988
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.010892721191048622

# %%
import fourier_1d_opt
config={
        "modes": 12,
        "width": 128,
        "learning_rate": 1e-4,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "batch_size": 50,
        "sampling_rate": 4,
        "padding": 9,
        "optimizer_type": 'adam',
        "loss_type": 'h1',
        "epochs": 1000,
        "GN": True,
        "mlp_LN": False,
        "lift_LN": False,
        "scheduler_type": 'onecyclelr',
    }

fourier_1d_opt.objective(**config)
# Out:
# 2229505
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [W Copy.cpp:244] Warning: Casting complex values to real discards the imaginary part (function operator())
# 0.0015156247466802596

# %%
# %load_ext autoreload
# %autoreload 2
import fourier_1d_opt
config={
        "modes": 12,
        "width": 128,
        "learning_rate": 1e-4,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": True,
        "kernel_type": 'c',
        "batch_size": 50,
        "sampling_rate": 4,
        "padding": 9,
        "optimizer_type": 'adam',
        "loss_type": 'h1',
        "epochs": 1000,
        "GN": True,
        "mlp_LN": False,
        "lift_LN": True,
        "scheduler_type": 'onecyclelr',
    }

fourier_1d_opt.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# use liftLN
# 2229761
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 0.0014052467048168182

# %%
# %load_ext autoreload
# %autoreload 2
import fourier_1d_opt
config={
        "modes": 12,
        "width": 128,
        "learning_rate": 1e-4,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": True,
        "kernel_type": 'c',
        "batch_size": 50,
        "sampling_rate": 4,
        "padding": 9,
        "optimizer_type": 'adam',
        "loss_type": 'h1',
        "epochs": 1000,
        "GN": True,
        "mlp_LN": False,
        "lift_LN": True,
        "scheduler_type": 'onecyclelr',
    }

fourier_1d_opt.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# use liftLN
# 2229761
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [W Copy.cpp:244] Warning: Casting complex values to real discards the imaginary part (function operator())
# 0.0019087782502174378

# %%
# %load_ext autoreload
# %autoreload 2
import fourier_1d_opt
config={
        "modes": 16,
        "width": 128,
        "learning_rate": 1e-4,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": True,
        "kernel_type": 'c',
        "batch_size": 20,
        "sampling_rate": 4,
        "padding": 9,
        "optimizer_type": 'adam',
        "loss_type": 'h1',
        "epochs": 500,
        "GN": True,
        "mlp_LN": False,
        "lift_LN": False,
        "scheduler_type": 'onecyclelr',
    }

fourier_1d_opt.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2311297
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0.0011661181785166265

# %%
# %load_ext autoreload
# %autoreload 2
import fourier_1d_opt
config={
        "modes": 16,
        "width": 128,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": True,
        "kernel_type": 'c',
        "batch_size": 20,
        "sampling_rate": 4,
        "padding": 9,
        "optimizer_type": 'adam',
        "loss_type": 'h1',
        "epochs": 500,
        "GN": True,
        "mlp_LN": False,
        "lift_LN": False,
        "scheduler_type": 'onecyclelr',
    }

fourier_1d_opt.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2311297
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0.00272502314299345

# %%
# %load_ext autoreload
# %autoreload 2
import fourier_1d_opt
config={
        "modes": 16,
        "width": 128,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": True,
        "kernel_type": 'c',
        "batch_size": 20,
        "sampling_rate": 4,
        "padding": 1,
        "optimizer_type": 'adam',
        "loss_type": 'h1',
        "epochs": 500,
        "GN": True,
        "mlp_LN": False,
        "lift_LN": False,
        "scheduler_type": 'onecyclelr',
    }

fourier_1d_opt.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2311297
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0.0026428987830877304

# %%
# %load_ext autoreload
# %autoreload 2
import fourier_1d_opt
config={
        "modes": 16,
        "width": 128,
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": True,
        "kernel_type": 'c',
        "batch_size": 20,
        "sampling_rate": 4,
        "padding": 1,
        "optimizer_type": 'adam',
        "loss_type": 'l2',
        "epochs": 100,
        "GN": True,
        "mlp_LN": False,
        "lift_LN": False,
        "scheduler_type": 'onecyclelr',
    }

fourier_1d_opt.objective(**config)
# Out:
# 2884865
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.001329897604882717

# %%
# %load_ext autoreload
# %autoreload 2
import fourier_1d_opt
config={
        "modes": 16,
        "width": 128,
        "learning_rate": 5e-4,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": True,
        "kernel_type": 'c',
        "batch_size": 20,
        "sampling_rate": 4,
        "padding": 1,
        "optimizer_type": 'adam',
        "loss_type": 'l2',
        "epochs": 100,
        "GN": True,
        "mlp_LN": False,
        "lift_LN": False,
        "scheduler_type": 'onecyclelr',
    }

fourier_1d_opt.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2884865
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.001314190812408924

# %%
# %load_ext autoreload
# %autoreload 2
import fourier_1d_opt
config={
        "modes": 16,
        "width": 128,
        "learning_rate": 1e-4,
        "weight_decay": 1e-4,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": True,
        "kernel_type": 'c',
        "batch_size": 20,
        "sampling_rate": 4,
        "padding": 1,
        "optimizer_type": 'adam',
        "loss_type": 'l2',
        "epochs": 500,
        "GN": True,
        "mlp_LN": False,
        "lift_LN": False,
        "scheduler_type": 'onecyclelr',
    }

fourier_1d_opt.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2884865
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0.0007099347561597824

# %%
# %load_ext autoreload
# %autoreload 2
import fourier_1d_opt
config={
        "modes": 12,
        "width": 128,
        "learning_rate": 1e-4,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": True,
        "kernel_type": 'c',
        "batch_size": 20,
        "sampling_rate": 4,
        "padding": 1,
        "optimizer_type": 'adam',
        "loss_type": 'l2',
        "epochs": 500,
        "GN": True,
        "mlp_LN": False,
        "lift_LN": False,
        "scheduler_type": 'onecyclelr',
    }

fourier_1d_opt.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 1787009
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0.0008261080831289292
