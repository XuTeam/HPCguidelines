# %%
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# h1 loss
# kernel size 3
import FNOtuning_hopt_multi
config={
        "modes": 14,
        "width": 64,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
    }
FNOtuning_hopt_multi.objective(**config)
# Out:
# 12968705
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0.01991467148065567

# %%
# h1 loss
# kernel size 3
import FNOtuning_hopt_multi
config={
        "modes": 14,
        "width": 64,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
    }
FNOtuning_hopt_multi.objective(**config)
# Out:
# 12968577
#   0%|          | 0/300 [00:00<?, ?it/s]
# 0.016511585414409637

# %%
# h1 loss
# kernel size 3
import FNOtuning_hopt_multi
config={
        "modes": 12,
        "width": 32,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
    }
FNOtuning_hopt_multi.objective(**config)
# Out:
# 2392513
#   0%|          | 0/300 [00:00<?, ?it/s]

# %%
# h1 loss
# kernel size 3
import FNOtuning_hopt_multi
config={
        "modes": 12,
        "width": 32,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
    }
FNOtuning_hopt_multi.objective(**config)
# Out:
# 2392513
#   0%|          | 0/300 [00:00<?, ?it/s]
# 0.013504234552383422

# %%
# h1 loss
# kernel size 3
import FNOtuning_hopt_multi
config={
        "modes": 14,
        "width": 64,
        "learning_rate": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
    }
FNOtuning_hopt_multi.objective(**config)
# Out:
# 12968705
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0.012795872539281845

# %%
# h1 loss
# kernel size 3 
# short cut
# only know a quater of the domain
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 64,
        "data": 'a4f1',
        "sampling_rate": 2,
        "learning_rate": 1e-3,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "scheduler_type": 'OneCycleLR',
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# 11989825
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.01429240196943283

# %%
# h1 loss
# kernel size 3 
# short cut
# LN for input 
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 32,
        "data": 'a4f1',
        "learning_rate": 1e-3,
        "num_spectral_layers": 5,
        "activation": 'gelu',
        "sampling_rate": 2, 
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "scheduler_type": 'OneCycleLR',
        "lift_LN": True,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# use liftLN
# 2999905
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.02127304971218109

# %%
# h1 loss
# kernel size 3 
# short cut
# LN for input 
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 32,
        "data": 'checkerm4',
        "sampling_rate": 4, 
        "learning_rate": 4e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'l2',
        "optimizer_type": 'adamw',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": True,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# use liftLN
# 2400833
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.46706916809082033

# %%
# h1 loss
# kernel size 3 
# short cut
# ScaleNormal for input 
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 32,
        "data": 'checkerm4',
        "sampling_rate": 4, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-3,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'l2',
        "optimizer_type": 'adamw',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2400769
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.5035489463806152

# %%
# h1 loss
# kernel size 3 
# short cut
# no normalizer for input 
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 32,
        "data": 'darcy20',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'l2',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2400769
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.014140057563781738

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 32,
        "data": 'darcy20',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'l2',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2400769
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.007190974950790405

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 32,
        "data": 'darcy20c6',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'l2',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2400769
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.22669352531433107

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy20c6',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 9593601
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.11491819381713868

# %%
# h1 loss
# kernel size 3 
# short cut
# no GN, but LN
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy20c6',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": True,
        "GN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# use liftLN
# 9593729
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.13450538635253906

# %%
# h1 loss
# kernel size 3 
# short cut
# no GN, but LN
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy20c6',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": True,
        "GN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# use liftLN
# 9593729
#   0%|          | 0/100 [00:00<?, ?it/s]
# [W Copy.cpp:244] Warning: Casting complex values to real discards the imaginary part (function operator())
# 0.014041389226913453

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 32,
        "data": 'darcy20c6',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'p',
        "epochs": 100,
        "loss_type": 'l2',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# 2376193
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.027249488234519958

# %%
# h1 loss
# kernel size 3 
# short cut
# no GN, but LN
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 64,
        "data": 'darcy15c10',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'h1',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": True,
        "GN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# use liftLN
# 9593729
#   0%|          | 0/100 [00:00<?, ?it/s]
# [W Copy.cpp:244] Warning: Casting complex values to real discards the imaginary part (function operator())
# 0.007749227434396743

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 32,
        "data": 'darcy15c10',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'c',
        "epochs": 100,
        "loss_type": 'l2',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2400769
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.011531544625759125

# %%
# h1 loss
# kernel size 3 
# short cut
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import fourier_2d_hopt_train
config={
        "modes": 12,
        "width": 32,
        "data": 'darcy15c10',
        "sampling_rate": 2, 
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,
        "num_spectral_layers": 4,
        "activation": 'gelu',    
        "mlp_hidden_dim": 128,
        "show_conv": True,
        "mode_threshold": False,
        "kernel_type": 'p',
        "epochs": 100,
        "loss_type": 'l2',
        "optimizer_type": 'adam',
        "scheduler_type": 'OneCycleLR',
        "lift_LN": False,
    }
fourier_2d_hopt_train.objective(**config)
# Out:
# 2376193
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.014034029543399811

# %%
from utilities3 import *

# %%
TEST_PATH = '/home/liuxinliang/fourier_neural_operator-master/data_generation/darcy/darcy_alpha2_tau20_512_test.mat'
reader = MatReader(TEST_PATH)
reader.load_file(TEST_PATH)

# %%
TEST_PATH = TRAIN_PATH = os.path.join(os.path.abspath(''),'data/piececonst_r421_N1024_smooth1.mat')
reader = MatReader(TEST_PATH)
reader.load_file(TEST_PATH)

# %%
x_test = reader.read_field('coeff')[:100,...]

# %%
x_test = x_test[:, np.newaxis, ...]

# %%
x_test.shape
# Out:
# torch.Size([100, 1, 1023, 1023])

# %%
conv1 = nn.Conv2d(1, 10, kernel_size=4, stride=3, padding=6)

# %%
y_test = conv1(x_test)

# %%
y_test.shape
# Out:
# torch.Size([100, 10, 344, 344])

# %%
(1023-4+2*6) // 3+1
# Out:
# 344

# %%
(1023-3+2) // 2+1
# Out:
# 512

# %%
512//8
# Out:
# 64

# %%
144//9
# Out:
# 16
